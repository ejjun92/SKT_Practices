# %% [markdown]
# # Matrices and Matrix Operations
#
# This function introduces various ways to create
# matrices and how to use them in TensorFlow

# %%
import numpy as np
import tensorflow as tf
from tensorflow.python.framework import ops
ops.reset_default_graph()

# %% [markdown]
# Start a graph session

# %%
sess = tf.Session()

# %% [markdown]
# ### Declaring matrices
#
# Identity Matrix:

# %%
identity_matrix = tf.diag([1.0,1.0,1.0])
print(sess.run(identity_matrix))
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# 2x3 random norm matrix:

# %%
A = tf.truncated_normal([2,3])
print(sess.run(A))
# Out:
# [[ 1.3226887   0.4454512  -0.93239874]
#  [-0.43964848 -1.0149133  -0.2837589 ]]

# %% [markdown]
# 2x3 constant matrix:

# %%
B = tf.fill([2,3], 5.0)
print(sess.run(B))
# Out:
# [[5. 5. 5.]
#  [5. 5. 5.]]

# %% [markdown]
# 3x2 random uniform matrix:

# %%
C = tf.random_uniform([3,2])
print(sess.run(C))
# Out:
# [[0.8898767  0.28621817]
#  [0.29506993 0.02740073]
#  [0.5540513  0.647426  ]]

# %% [markdown]
# Create matrix from np array:

# %%
D = tf.convert_to_tensor(np.array([[1., 2., 3.], [-3., -7., -1.], [0., 5., -2.]]))
print(sess.run(D))
# Out:
# [[ 1.  2.  3.]
#  [-3. -7. -1.]
#  [ 0.  5. -2.]]

# %% [markdown]
# ### Matrix Operations
#
# Matrix addition/subtraction:

# %%
print(sess.run(A+B))
print(sess.run(B-B))
# Out:
# [[3.871006  6.4390783 3.6736102]
#  [4.228157  4.5462103 6.223293 ]]
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %% [markdown]
# Matrix Multiplication:

# %%
print(sess.run(tf.matmul(B, identity_matrix)))
# Out:
# [[5. 5. 5.]
#  [5. 5. 5.]]

# %% [markdown]
# Matrix Transpose:

# %%
print(sess.run(tf.transpose(C)))
# Out:
# [[0.33493292 0.69611394 0.52723086]
#  [0.88865614 0.9140583  0.12489653]]

# %% [markdown]
# Matrix Determinant:

# %%
print(sess.run(tf.matrix_determinant(D)))
# Out:
# -37.99999999999999

# %% [markdown]
# Matrix Inverse:

# %%
print(sess.run(tf.matrix_inverse(D)))
# Out:
# [[-0.5        -0.5        -0.5       ]
#  [ 0.15789474  0.05263158  0.21052632]
#  [ 0.39473684  0.13157895  0.02631579]]

# %% [markdown]
# Eigenvalues and Eigenvectors:  We use `tf.self_adjoint_eig()` function, which returns two objects, first one is an array of eigenvalues, the second is a matrix of the eigenvectors.

# %%
eigenvalues, eigenvectors = sess.run(tf.self_adjoint_eig(D))
print(eigenvalues)
print(eigenvectors)
# Out:
# [-10.65907521  -0.22750691   2.88658212]
# [[ 0.21749542  0.63250104 -0.74339638]
#  [ 0.84526515  0.2587998   0.46749277]
#  [-0.4880805   0.73004459  0.47834331]]
